# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
def split_dataset_by_brand(dataset):
    brands = set(dataset["Brand"])
    return { brand: dataset[dataset["Brand"] == brand] for brand in brands }

# %%
dataset = pd.read_csv('./clf_data.csv')
dataset
# Out:
#       Unnamed: 0                     img   Brand
# 0              0       0-iwc-13109.0.png     iwc
# 1              1        1-iwc-4899.0.png     iwc
# 2              2       2-iwc-10139.0.png     iwc
# 3              3        3-iwc-3239.0.png     iwc
# 4              4        4-iwc-8499.0.png     iwc
# ...          ...                     ...     ...
# 3637        3637  3637-zenith-2750.0.png  zenith
# 3638        3638  3638-zenith-4895.0.png  zenith
# 3639        3639  3639-zenith-5950.0.png  zenith
# 3640        3640  3640-zenith-6409.0.png  zenith
# 3641        3641  3641-zenith-4999.0.png  zenith
#
# [3642 rows x 3 columns]

# %%
split_dataset_by_brand(dataset)
# Out:
# {'nomos':       Unnamed: 0                    img  Brand
#  912          912   912-nomos-3269.0.png  nomos
#  913          913   913-nomos-2639.0.png  nomos
#  914          914   914-nomos-2329.0.png  nomos
#  915          915    915-nomos-989.0.png  nomos
#  916          916   916-nomos-1716.0.png  nomos
#  ...          ...                    ...    ...
#  1210        1210  1210-nomos-2945.0.png  nomos
#  1211        1211  1211-nomos-3420.0.png  nomos
#  1212        1212  1212-nomos-3145.0.png  nomos
#  1213        1213  1213-nomos-1549.0.png  nomos
#  1214        1214  1214-nomos-1869.0.png  nomos
#
#  [303 rows x 3 columns],
#  'seiko':       Unnamed: 0                    img  Brand
#  3038        3038  3038-seiko-2959.0.png  seiko
#  3039        3039   3039-seiko-356.0.png  seiko
#  3040        3040  3040-seiko-7400.0.png  seiko
#  3041        3041  3041-seiko-3900.0.png  seiko
#  3042        3042  3042-seiko-5230.0.png  seiko
#  ...          ...                    ...    ...
#  3334        3334   3334-seiko-750.0.png  seiko
#  3335        3335   3335-seiko-975.0.png  seiko
#  3336        3336   3336-seiko-145.0.png  seiko
#  3337        3337   3337-seiko-389.0.png  seiko
#  3338        3338  3338-seiko-6500.0.png  seiko
#
#  [301 rows x 3 columns],
#  'cartier':       Unnamed: 0                       img    Brand
#  2128        2128   2128-cartier-4500.0.png  cartier
#  2129        2129   2129-cartier-3959.0.png  cartier
#  2130        2130   2130-cartier-6609.0.png  cartier
#  2131        2131   2131-cartier-3250.0.png  cartier
#  2132        2132   2132-cartier-4650.0.png  cartier
#  ...          ...                       ...      ...
#  2426        2426   2426-cartier-3835.0.png  cartier
#  2427        2427   2427-cartier-3490.0.png  cartier
#  2428        2428   2428-cartier-7350.0.png  cartier
#  2429        2429  2429-cartier-31600.0.png  cartier
#  2430        2430   2430-cartier-8950.0.png  cartier
#
#  [303 rows x 3 columns],
#  'breitling':       Unnamed: 0                         img      Brand
#  1518        1518   1518-breitling-3250.0.png  breitling
#  1519        1519   1519-breitling-6599.0.png  breitling
#  1520        1520   1520-breitling-8200.0.png  breitling
#  1521        1521   1521-breitling-5999.0.png  breitling
#  1522        1522  1522-breitling-14500.0.png  breitling
#  ...          ...                         ...        ...
#  1816        1816   1816-breitling-6999.0.png  breitling
#  1817        1817   1817-breitling-4950.0.png  breitling
#  1818        1818   1818-breitling-8400.0.png  breitling
#  1819        1819   1819-breitling-2650.0.png  breitling
#  1820        1820  1820-breitling-26000.0.png  breitling
#
#  [303 rows x 3 columns],
#  'omega':       Unnamed: 0                     img  Brand
#  1821        1821   1821-omega-2499.0.png  omega
#  1822        1822   1822-omega-1269.0.png  omega
#  1823        1823   1823-omega-2519.0.png  omega
#  1824        1824   1824-omega-7999.0.png  omega
#  1825        1825  1825-omega-11999.0.png  omega
#  ...          ...                     ...    ...
#  2123        2123   2123-omega-4750.0.png  omega
#  2124        2124   2124-omega-4999.0.png  omega
#  2125        2125   2125-omega-3890.0.png  omega
#  2126        2126   2126-omega-3500.0.png  omega
#  2127        2127   2127-omega-8975.0.png  omega
#
#  [307 rows x 3 columns],
#  'iwc':      Unnamed: 0                 img Brand
#  0             0   0-iwc-13109.0.png   iwc
#  1             1    1-iwc-4899.0.png   iwc
#  2             2   2-iwc-10139.0.png   iwc
#  3             3    3-iwc-3239.0.png   iwc
#  4             4    4-iwc-8499.0.png   iwc
#  ..          ...                 ...   ...
#  299         299  299-iwc-3740.0.png   iwc
#  300         300  300-iwc-4375.0.png   iwc
#  301         301  301-iwc-5199.0.png   iwc
#  302         302  302-iwc-5400.0.png   iwc
#  303         303  303-iwc-3790.0.png   iwc
#
#  [304 rows x 3 columns],
#  'movado':      Unnamed: 0                     img   Brand
#  612         612   612-movado-1895.0.png  movado
#  613         613  613-movado-12500.0.png  movado
#  614         614   614-movado-2994.0.png  movado
#  615         615    615-movado-445.0.png  movado
#  616         616   616-movado-9995.0.png  movado
#  ..          ...                     ...     ...
#  907         907    907-movado-425.0.png  movado
#  908         908   908-movado-1650.0.png  movado
#  909         909   909-movado-1250.0.png  movado
#  910         910    910-movado-655.0.png  movado
#  911         911    911-movado-200.0.png  movado
#
#  [300 rows x 3 columns],
#  'audemarspiguet':       Unnamed: 0                               img           Brand
#  1215        1215  1215-audemarspiguet-214299.0.png  audemarspiguet
#  1216        1216   1216-audemarspiguet-33673.0.png  audemarspiguet
#  1217        1217   1217-audemarspiguet-23649.0.png  audemarspiguet
#  1218        1218   1218-audemarspiguet-28500.0.png  audemarspiguet
#  1219        1219   1219-audemarspiguet-24999.0.png  audemarspiguet
#  ...          ...                               ...             ...
#  1513        1513  1513-audemarspiguet-144995.0.png  audemarspiguet
#  1514        1514   1514-audemarspiguet-34400.0.png  audemarspiguet
#  1515        1515   1515-audemarspiguet-21500.0.png  audemarspiguet
#  1516        1516  1516-audemarspiguet-167299.0.png  audemarspiguet
#  1517        1517   1517-audemarspiguet-37000.0.png  audemarspiguet
#
#  [303 rows x 3 columns],
#  'patekphilippe':       Unnamed: 0                                      img          Brand
#  2431        2431           2431-patekphilippe-55349.0.png  patekphilippe
#  2432        2432           2432-patekphilippe-59500.0.png  patekphilippe
#  2433        2433           2433-patekphilippe-22068.0.png  patekphilippe
#  2434        2434           2434-patekphilippe-51499.0.png  patekphilippe
#  2435        2435           2435-patekphilippe-36000.0.png  patekphilippe
#  ...          ...                                      ...            ...
#  2733        2733           2733-patekphilippe-47900.0.png  patekphilippe
#  2734        2734           2734-patekphilippe-57350.0.png  patekphilippe
#  2735        2735           2735-patekphilippe-94999.0.png  patekphilippe
#  2736        2736           2736-patekphilippe-99295.0.png  patekphilippe
#  2737        2737  2737-patekphilippe-Price on request.png  patekphilippe
#
#  [307 rows x 3 columns],
#  'zenith':       Unnamed: 0                     img   Brand
#  3339        3339  3339-zenith-4569.0.png  zenith
#  3340        3340  3340-zenith-5049.0.png  zenith
#  3341        3341  3341-zenith-5199.0.png  zenith
#  3342        3342  3342-zenith-5675.0.png  zenith
#  3343        3343  3343-zenith-4000.0.png  zenith
#  ...          ...                     ...     ...
#  3637        3637  3637-zenith-2750.0.png  zenith
#  3638        3638  3638-zenith-4895.0.png  zenith
#  3639        3639  3639-zenith-5950.0.png  zenith
#  3640        3640  3640-zenith-6409.0.png  zenith
#  3641        3641  3641-zenith-4999.0.png  zenith
#
#  [303 rows x 3 columns],
#  'rolex':      Unnamed: 0                    img  Brand
#  304         304  304-rolex-18900.0.png  rolex
#  305         305  305-rolex-11599.0.png  rolex
#  306         306  306-rolex-11368.0.png  rolex
#  307         307  307-rolex-55500.0.png  rolex
#  308         308  308-rolex-17999.0.png  rolex
#  ..          ...                    ...    ...
#  607         607  607-rolex-11180.0.png  rolex
#  608         608  608-rolex-16760.0.png  rolex
#  609         609  609-rolex-27999.0.png  rolex
#  610         610  610-rolex-15494.0.png  rolex
#  611         611  611-rolex-35500.0.png  rolex
#
#  [308 rows x 3 columns],
#  'gucci':       Unnamed: 0                    img  Brand
#  2738        2738  2738-gucci-4999.0.png  gucci
#  2739        2739   2739-gucci-665.0.png  gucci
#  2740        2740  2740-gucci-1300.0.png  gucci
#  2741        2741   2741-gucci-484.0.png  gucci
#  2742        2742   2742-gucci-249.0.png  gucci
#  ...          ...                    ...    ...
#  3033        3033   3033-gucci-326.0.png  gucci
#  3034        3034   3034-gucci-660.0.png  gucci
#  3035        3035   3035-gucci-849.0.png  gucci
#  3036        3036   3036-gucci-620.0.png  gucci
#  3037        3037   3037-gucci-818.0.png  gucci
#
#  [300 rows x 3 columns]}

# %%
from sklearn.model_selection import train_test_split
import numpy as np
def train_validate_test_split(df, train_percent=.8, validate_percent=.2, seed=None):
    np.random.seed(seed)
    perm = np.random.permutation(df.index)
    m = len(df.index)
    print("LEN",m)
    train_end = int(train_percent * m)
    validate_end = int(validate_percent * m) + train_end
    
    train = df.iloc[perm[:train_end]]
    print("WORKS")
    validate = df.iloc[perm[train_end:validate_end]]
    test = df.iloc[perm[validate_end:]]
    return train, validate, test


def split_dataset(ds_by_brand, train=0.8,val=0.1,test=0.1):
    train = pd.DataFrame()
    val = pd.DataFrame()
    test = pd.DataFrame()
    for brand in ds_by_brand:
        tr,ts,v = train_validate_test_split(ds_by_brand[brand])
        print(tr,ts,v)
        train.append(tr)
        val.append(v)
        test.append(ts)
        
    return train,val,test

# %%
train,val,test = split_dataset(split_dataset_by_brand(dataset))
# Out:
# LEN 303
# WORKS
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Miniconda3\envs\ml\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    1468         try:
# -> 1469             return self.obj._take_with_is_copy(key, axis=axis)
#    1470         except IndexError as err:
#
# ~\Miniconda3\envs\ml\lib\site-packages\pandas\core\generic.py in _take_with_is_copy(self, indices, axis)
#    3353         """
# -> 3354         result = self.take(indices=indices, axis=axis)
#    3355         # Maybe set copy if we didn't actually change the index.
#
# ~\Miniconda3\envs\ml\lib\site-packages\pandas\core\generic.py in take(self, indices, axis, is_copy, **kwargs)
#    3340
# -> 3341         new_data = self._mgr.take(
#    3342             indices, axis=self._get_block_manager_axis(axis), verify=True
#
# ~\Miniconda3\envs\ml\lib\site-packages\pandas\core\internals\managers.py in take(self, indexer, axis, verify, convert)
#    1406         if convert:
# -> 1407             indexer = maybe_convert_indices(indexer, n)
#    1408
#
# ~\Miniconda3\envs\ml\lib\site-packages\pandas\core\indexers.py in maybe_convert_indices(indices, n)
#     249     if mask.any():
# --> 250         raise IndexError("indices are out-of-bounds")
#     251     return indices
#
# IndexError: indices are out-of-bounds
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# <ipython-input-35-5c9b8342680f> in <module>
# ----> 1 train,val,test = split_dataset(split_dataset_by_brand(dataset))
#
# <ipython-input-34-d2b689dafb14> in split_dataset(ds_by_brand, train, val, test)
#      20     test = pd.DataFrame()
#      21     for brand in ds_by_brand:
# ---> 22         tr,ts,v = train_validate_test_split(ds_by_brand[brand])
#      23         print(tr,ts,v)
#      24         train.append(tr)
#
# <ipython-input-34-d2b689dafb14> in train_validate_test_split(df, train_percent, validate_percent, seed)
#       9     validate_end = int(validate_percent * m) + train_end
#      10     print("WORKS")
# ---> 11     train = df.iloc[perm[:train_end]]
#      12     validate = df.iloc[perm[train_end:validate_end]]
#      13     test = df.iloc[perm[validate_end:]]
#
# ~\Miniconda3\envs\ml\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~\Miniconda3\envs\ml\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1485         # a list of integers
#    1486         elif is_list_like_indexer(key):
# -> 1487             return self._get_list_axis(key, axis=axis)
#    1488
#    1489         # a single integer
#
# ~\Miniconda3\envs\ml\lib\site-packages\pandas\core\indexing.py in _get_list_axis(self, key, axis)
#    1470         except IndexError as err:
#    1471             # re-raise with different error message
# -> 1472             raise IndexError("positional indexers are out-of-bounds") from err
#    1473
#    1474     def _getitem_axis(self, key, axis: int):
#
# IndexError: positional indexers are out-of-bounds
